# %%
#importing libraries to be used
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') 
from sklearn.preprocessing import MinMaxScaler 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
# Out:
# C:\Users\KRISHA\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# data_importing
df = pd.read_csv("Downloads/NFLX.csv")
# fetching first 10 rows of dataset
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %%
df.shape
# Out:
# (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.count()
# Out:
# Date         1009
# Open         1009
# High         1009
# Low          1009
# Close        1009
# Adj Close    1009
# Volume       1009
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Check for required columns
df = df[['Date','Open','Close']] 

# converting object dtype of date column to datetime dtype

df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.split()[0]))

# %%
df.set_index('Date',drop=True,inplace=True) 
df.head(10)
# Out:
#                   Open       Close
# Date
# 2018-02-05  262.000000  254.259995
# 2018-02-06  247.699997  265.720001
# 2018-02-07  266.579987  264.559998
# 2018-02-08  267.079987  250.100006
# 2018-02-09  253.850006  249.470001
# 2018-02-12  252.139999  257.950012
# 2018-02-13  257.290009  258.269989
# 2018-02-14  260.470001  266.000000
# 2018-02-15  270.029999  280.269989
# 2018-02-16  278.730011  278.519989

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'Close'}>]], dtype=object)

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='green')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 Open     Close
# Date
# 2018-02-05  0.061253  0.044516
# 2018-02-06  0.030059  0.069548
# 2018-02-07  0.071243  0.067015
# 2018-02-08  0.072334  0.035430
# 2018-02-09  0.043474  0.034053
# 2018-02-12  0.039744  0.052576
# 2018-02-13  0.050978  0.053275
# 2018-02-14  0.057915  0.070160
# 2018-02-15  0.078769  0.101330
# 2018-02-16  0.097747  0.097508

# %%
# splitting the data into train and test set
# Select 75 % for train and 25 % for test
training_size = round(len(df) * 0.75)

# %%
training_size
# Out:
# 757

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((757, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((707, 50, 2), (707, 2), (202, 50, 2), (202, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=25, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=25))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 25)            2800
#
#  dropout (Dropout)           (None, 50, 25)            0
#
#  lstm_1 (LSTM)               (None, 25)                5100
#
#  dense (Dense)               (None, 2)                 52
#
# =================================================================
# Total params: 7952 (31.06 KB)
# Trainable params: 7952 (31.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0015 - mean_absolute_error: 0.0289 - val_loss: 0.0034 - val_mean_absolute_error: 0.0408
# Epoch 2/100
# 23/23 [==============================] - 1s 39ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 0.0031 - val_mean_absolute_error: 0.0374
# Epoch 3/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0015 - mean_absolute_error: 0.0292 - val_loss: 0.0030 - val_mean_absolute_error: 0.0366
# Epoch 4/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0030 - val_mean_absolute_error: 0.0369
# Epoch 5/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0038 - val_mean_absolute_error: 0.0461
# Epoch 6/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0014 - mean_absolute_error: 0.0275 - val_loss: 0.0031 - val_mean_absolute_error: 0.0382
# Epoch 7/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 0.0028 - val_mean_absolute_error: 0.0355
# Epoch 8/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0014 - mean_absolute_error: 0.0284 - val_loss: 0.0031 - val_mean_absolute_error: 0.0377
# Epoch 9/100
# 23/23 [==============================] - 1s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 0.0027 - val_mean_absolute_error: 0.0349
# Epoch 10/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0032 - val_mean_absolute_error: 0.0406
# Epoch 11/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0014 - mean_absolute_error: 0.0277 - val_loss: 0.0028 - val_mean_absolute_error: 0.0351
# Epoch 12/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0268 - val_loss: 0.0067 - val_mean_absolute_error: 0.0691
# Epoch 13/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0271 - val_loss: 0.0027 - val_mean_absolute_error: 0.0351
# Epoch 14/100
# 23/23 [==============================] - 1s 39ms/step - loss: 0.0013 - mean_absolute_error: 0.0269 - val_loss: 0.0032 - val_mean_absolute_error: 0.0398
# Epoch 15/100
# 23/23 [==============================] - 1s 39ms/step - loss: 0.0014 - mean_absolute_error: 0.0281 - val_loss: 0.0040 - val_mean_absolute_error: 0.0487
# Epoch 16/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0027 - val_mean_absolute_error: 0.0353
# Epoch 17/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 0.0026 - val_mean_absolute_error: 0.0346
# Epoch 18/100
# 23/23 [==============================] - 1s 41ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 0.0025 - val_mean_absolute_error: 0.0340
# Epoch 19/100
# 23/23 [==============================] - 1s 41ms/step - loss: 0.0012 - mean_absolute_error: 0.0259 - val_loss: 0.0025 - val_mean_absolute_error: 0.0339
# Epoch 20/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0012 - mean_absolute_error: 0.0254 - val_loss: 0.0030 - val_mean_absolute_error: 0.0378
# Epoch 21/100
# 23/23 [==============================] - 1s 41ms/step - loss: 0.0011 - mean_absolute_error: 0.0248 - val_loss: 0.0027 - val_mean_absolute_error: 0.0349
# Epoch 22/100
# 23/23 [==============================] - 1s 41ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 0.0049 - val_mean_absolute_error: 0.0559
# Epoch 23/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0263 - val_loss: 0.0037 - val_mean_absolute_error: 0.0448
# Epoch 24/100
# 23/23 [==============================] - 1s 42ms/step - loss: 0.0012 - mean_absolute_error: 0.0262 - val_loss: 0.0028 - val_mean_absolute_error: 0.0361
# Epoch 25/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 0.0024 - val_mean_absolute_error: 0.0333
# Epoch 26/100
# 23/23 [==============================] - 1s 37ms/step - loss: 9.7954e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0026 - val_mean_absolute_error: 0.0349
# Epoch 27/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - val_loss: 0.0031 - val_mean_absolute_error: 0.0398
# Epoch 28/100
# 23/23 [==============================] - 1s 36ms/step - loss: 9.6714e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0029 - val_mean_absolute_error: 0.0374
# Epoch 29/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0025 - val_mean_absolute_error: 0.0343
# Epoch 30/100
# 23/23 [==============================] - 1s 36ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 0.0025 - val_mean_absolute_error: 0.0344
# Epoch 31/100
# 23/23 [==============================] - 1s 37ms/step - loss: 9.5127e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0041 - val_mean_absolute_error: 0.0505
# Epoch 32/100
# 23/23 [==============================] - 1s 38ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 0.0022 - val_mean_absolute_error: 0.0317
# Epoch 33/100
# 23/23 [==============================] - 1s 38ms/step - loss: 9.2680e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0025 - val_mean_absolute_error: 0.0342
# Epoch 34/100
# 23/23 [==============================] - 1s 39ms/step - loss: 9.2657e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0030 - val_mean_absolute_error: 0.0388
# Epoch 35/100
# 23/23 [==============================] - 1s 39ms/step - loss: 8.6213e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0022 - val_mean_absolute_error: 0.0320
# Epoch 36/100
# 23/23 [==============================] - 1s 39ms/step - loss: 9.1998e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0041 - val_mean_absolute_error: 0.0517
# Epoch 37/100
# 23/23 [==============================] - 1s 40ms/step - loss: 0.0010 - mean_absolute_error: 0.0239 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 38/100
# 23/23 [==============================] - 1s 41ms/step - loss: 8.4882e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0028 - val_mean_absolute_error: 0.0376
# Epoch 39/100
# 23/23 [==============================] - 1s 47ms/step - loss: 8.2681e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0022 - val_mean_absolute_error: 0.0321
# Epoch 40/100
# 23/23 [==============================] - 1s 40ms/step - loss: 8.0447e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0022 - val_mean_absolute_error: 0.0316
# Epoch 41/100
# 23/23 [==============================] - 1s 43ms/step - loss: 8.4499e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0026 - val_mean_absolute_error: 0.0362
# Epoch 42/100
# 23/23 [==============================] - 1s 43ms/step - loss: 8.3466e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0028 - val_mean_absolute_error: 0.0390
# Epoch 43/100
# 23/23 [==============================] - 1s 42ms/step - loss: 7.9434e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 44/100
# 23/23 [==============================] - 1s 41ms/step - loss: 7.5660e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0033 - val_mean_absolute_error: 0.0433
# Epoch 45/100
# 23/23 [==============================] - 1s 43ms/step - loss: 9.3710e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 46/100
# 23/23 [==============================] - 1s 43ms/step - loss: 8.7243e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0023 - val_mean_absolute_error: 0.0340
# Epoch 47/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.2978e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0019 - val_mean_absolute_error: 0.0296
# Epoch 48/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.9159e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0020 - val_mean_absolute_error: 0.0314
# Epoch 49/100
# 23/23 [==============================] - 1s 46ms/step - loss: 8.2477e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 50/100
# 23/23 [==============================] - 1s 43ms/step - loss: 8.1567e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0019 - val_mean_absolute_error: 0.0293
# Epoch 51/100
# 23/23 [==============================] - 1s 49ms/step - loss: 7.3420e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0018 - val_mean_absolute_error: 0.0286
# Epoch 52/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.1267e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0018 - val_mean_absolute_error: 0.0276
# Epoch 53/100
# 23/23 [==============================] - 1s 45ms/step - loss: 7.6771e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 54/100
# 23/23 [==============================] - 1s 44ms/step - loss: 8.2263e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0022 - val_mean_absolute_error: 0.0335
# Epoch 55/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.8842e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0024 - val_mean_absolute_error: 0.0339
# Epoch 56/100
# 23/23 [==============================] - 1s 44ms/step - loss: 7.1110e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0017 - val_mean_absolute_error: 0.0278
# Epoch 57/100
# 23/23 [==============================] - 1s 46ms/step - loss: 6.9167e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
# Epoch 58/100
# 23/23 [==============================] - 1s 46ms/step - loss: 7.5472e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0032 - val_mean_absolute_error: 0.0454
# Epoch 59/100
# 23/23 [==============================] - 1s 43ms/step - loss: 7.3016e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0020 - val_mean_absolute_error: 0.0318
# Epoch 60/100
# 23/23 [==============================] - 1s 42ms/step - loss: 7.1331e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319
# Epoch 61/100
# 23/23 [==============================] - 1s 42ms/step - loss: 8.3459e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0015 - val_mean_absolute_error: 0.0250
# Epoch 62/100
# 23/23 [==============================] - 1s 41ms/step - loss: 7.1024e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0019 - val_mean_absolute_error: 0.0303
# Epoch 63/100
# 23/23 [==============================] - 1s 42ms/step - loss: 6.6911e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0025 - val_mean_absolute_error: 0.0376
# Epoch 64/100
# 23/23 [==============================] - 1s 41ms/step - loss: 7.1325e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0015 - val_mean_absolute_error: 0.0250
# Epoch 65/100
# 23/23 [==============================] - 1s 42ms/step - loss: 6.8461e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0014 - val_mean_absolute_error: 0.0250
# Epoch 66/100
# 23/23 [==============================] - 1s 41ms/step - loss: 7.9113e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0016 - val_mean_absolute_error: 0.0262
# Epoch 67/100
# 23/23 [==============================] - 1s 41ms/step - loss: 6.7869e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0018 - val_mean_absolute_error: 0.0297
# Epoch 68/100
# 23/23 [==============================] - 1s 41ms/step - loss: 6.3036e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0017 - val_mean_absolute_error: 0.0283
# Epoch 69/100
# 23/23 [==============================] - 1s 41ms/step - loss: 6.2434e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0015 - val_mean_absolute_error: 0.0250
# Epoch 70/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.6522e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0015 - val_mean_absolute_error: 0.0264
# Epoch 71/100
# 23/23 [==============================] - 1s 38ms/step - loss: 6.4075e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0020 - val_mean_absolute_error: 0.0323
# Epoch 72/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.0430e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0016 - val_mean_absolute_error: 0.0277
# Epoch 73/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.8518e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 74/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.3474e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0022 - val_mean_absolute_error: 0.0366
# Epoch 75/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.3280e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0020 - val_mean_absolute_error: 0.0328
# Epoch 76/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.9588e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0013 - val_mean_absolute_error: 0.0224
# Epoch 77/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.1011e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0021 - val_mean_absolute_error: 0.0329
# Epoch 78/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.2689e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0013 - val_mean_absolute_error: 0.0242
# Epoch 79/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.2224e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0014 - val_mean_absolute_error: 0.0249
# Epoch 80/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.6069e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0017 - val_mean_absolute_error: 0.0292
# Epoch 81/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.7821e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 82/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.1560e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0012 - val_mean_absolute_error: 0.0222
# Epoch 83/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.4427e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0021 - val_mean_absolute_error: 0.0324
# Epoch 84/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.8582e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 85/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.5324e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0014 - val_mean_absolute_error: 0.0238
# Epoch 86/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.8859e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
# Epoch 87/100
# 23/23 [==============================] - 1s 40ms/step - loss: 6.1026e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0012 - val_mean_absolute_error: 0.0225
# Epoch 88/100
# 23/23 [==============================] - 1s 39ms/step - loss: 6.4415e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0018 - val_mean_absolute_error: 0.0289
# Epoch 89/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.7304e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0014 - val_mean_absolute_error: 0.0251
# Epoch 90/100
# 23/23 [==============================] - 1s 40ms/step - loss: 5.6798e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0014 - val_mean_absolute_error: 0.0245
# Epoch 91/100
# 23/23 [==============================] - 1s 38ms/step - loss: 6.0159e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0023 - val_mean_absolute_error: 0.0333
# Epoch 92/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.4620e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0014 - val_mean_absolute_error: 0.0246
# Epoch 93/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.5228e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0019 - val_mean_absolute_error: 0.0301
# Epoch 94/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.1387e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0014 - val_mean_absolute_error: 0.0243
# Epoch 95/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.3404e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0015 - val_mean_absolute_error: 0.0254
# Epoch 96/100
# 23/23 [==============================] - 1s 39ms/step - loss: 5.8826e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0022 - val_mean_absolute_error: 0.0336
# Epoch 97/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.7177e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
# Epoch 98/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.6314e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0023 - val_mean_absolute_error: 0.0351
# Epoch 99/100
# 23/23 [==============================] - 1s 37ms/step - loss: 5.4510e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0018 - val_mean_absolute_error: 0.0287
# Epoch 100/100
# 23/23 [==============================] - 1s 38ms/step - loss: 5.1860e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0015 - val_mean_absolute_error: 0.0258

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 0s 12ms/step
# array([[0.7064844 , 0.68761164],
#        [0.61534923, 0.60808444],
#        [0.61232615, 0.60031784],
#        [0.6170064 , 0.6030455 ],
#        [0.62703556, 0.6126317 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[0.7064844 , 0.68761164],
#        [0.61534923, 0.60808444],
#        [0.61232615, 0.60031784],
#        [0.6170064 , 0.6030455 ],
#        [0.62703556, 0.6126317 ]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df1 = pd.concat([df.iloc[-202:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-202:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df1[['Open','Close']] = MMS.inverse_transform(df1[['Open','Close']])
df1.head()
# Out:
#                 Open     Close  open_predicted  close_predicted
# Date
# 2021-04-21  0.597867  0.600730        0.706484         0.687612
# 2021-04-22  0.610562  0.600467        0.615349         0.608084
# 2021-04-23  0.600070  0.593412        0.612326         0.600318
# 2021-04-26  0.595162  0.603788        0.617006         0.603046
# 2021-04-27  0.607945  0.593412        0.627036         0.612632

# %%
# plotting the actual open and predicted open prices on date index
df1[['Open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df1[['Close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df1
# Out:
#                 Open     Close  open_predicted  close_predicted
# Date
# 2021-04-21  0.597867  0.600730        0.706484         0.687612
# 2021-04-22  0.610562  0.600467        0.615349         0.608084
# 2021-04-23  0.600070  0.593412        0.612326         0.600318
# 2021-04-26  0.595162  0.603788        0.617006         0.603046
# 2021-04-27  0.607945  0.593412        0.627036         0.612632
# ...              ...       ...             ...              ...
# 2022-01-31  0.366577  0.422140        0.390994         0.391927
# 2022-02-01  0.434178  0.487648        0.446483         0.443954
# 2022-02-02  0.467531  0.427251        0.511379         0.507496
# 2022-02-03  0.409048  0.375090        0.495810         0.497803
# 2022-02-04  0.378226  0.385072        0.429885         0.438773
#
# [202 rows x 4 columns]

# %%
# Creating a dataframe and adding 10 days to existing index 

df2 = pd.concat([df1,pd.DataFrame(columns=df1.columns,
                                        index=pd.date_range(start=df1.index[-1], periods=11, freq='D'))],axis=0)
df2['2022-02-03':'2022-02-21']
# Out:
#                 Open     Close open_predicted close_predicted
# 2022-02-03  0.409048   0.37509        0.49581        0.497803
# 2022-02-04  0.378226  0.385072       0.429885        0.438773
# 2022-02-04       NaN       NaN            NaN             NaN
# 2022-02-05       NaN       NaN            NaN             NaN
# 2022-02-06       NaN       NaN            NaN             NaN
# 2022-02-07       NaN       NaN            NaN             NaN
# 2022-02-08       NaN       NaN            NaN             NaN
# 2022-02-09       NaN       NaN            NaN             NaN
# 2022-02-10       NaN       NaN            NaN             NaN
# 2022-02-11       NaN       NaN            NaN             NaN
# 2022-02-12       NaN       NaN            NaN             NaN
# 2022-02-13       NaN       NaN            NaN             NaN
# 2022-02-14       NaN       NaN            NaN             NaN

# %%
# creating a DataFrame and filling values of open and close column
forthcoming_prediction = pd.DataFrame(columns=['open','close'],index=df1.index)
forthcoming_prediction.index=pd.to_datetime(forthcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  forthcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
# inversing Normalization/scaling
forthcoming_prediction[['open','close']] = MMS.inverse_transform(forthcoming_prediction[['open','close']])

# %%
# plotting forthcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Open'],label='Current Open Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df1.loc['2022-01-24':,'Close'],label='Current close Price')
ax.plot(forthcoming_prediction.loc['2022-01-24':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('forthcoming close price prediction',size=15)
ax.legend()
fig.show()
